# %% [markdown]
# <div style="align: center;">
#     <br>
#     <img src="https://www.nyc.gov/assets/tlc/images/content/hero/MRP-Closing-Week.jpg" style="display:block; margin:auto; width:65%; height:250px;">
# </div><br><br>
#
# <div style="letter-spacing:normal; opacity:1.;">
# <!--   https://xkcd.com/color/rgb/   -->
#   <p style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>TLC Trip Record Data</strong></p>
#
#   <p style="text-align:center; background-color:romance; color: Jaguar; border-radius:10px; font-family:monospace;
#             line-height:1.4; font-size:22px; font-weight:normal; text-transform: capitalize; padding: 5px;"
#      >Machine Learning Module: PREFECT - Ride Duration Prediction using Regression Analysis<br>( MLFLOW & PREFECT )</p>
# </div>
#
# - https://github.com/discdiver/prefect-mlops-zoomcamp
# - https://mlflow.org/docs/0.7.0/index.html

# %% [markdown]
# **Dataset Info**
#
#
# **Context**
#
# Yellow and green taxi trip records include fields capturing pick-up and drop-off dates/times, pick-up and drop-off locations, trip distances, itemized fares, rate types, payment types, and driver-reported passenger counts. The data used in the attached datasets were collected and provided to the NYC Taxi and Limousine Commission (TLC) by technology providers authorized under the Taxicab & Livery Passenger Enhancement Programs (TPEP/LPEP). The trip data was not created by the TLC, and TLC makes no representations as to the accuracy of these data.
#
# For-Hire Vehicle (“FHV”) trip records include fields capturing the dispatching base license number and the pick-up date, time, and taxi zone location ID (shape file below). These records are generated from the FHV Trip Record submissions made by bases. Note: The TLC publishes base trip record data as submitted by the bases, and we cannot guarantee or confirm their accuracy or completeness. Therefore, this may not represent the total amount of trips dispatched by all TLC-licensed bases. The TLC performs routine reviews of the records and takes enforcement actions when necessary to ensure, to the extent possible, complete and accurate information.
#
#
# **ATTENTION!**
#
# On 05/13/2022, we are making the following changes to trip record files:
#
# - All files will be stored in the PARQUET format. Please see the ‘Working With PARQUET Format’ under the Data Dictionaries and MetaData section.
# - Trip data will be published monthly (with two months delay) instead of bi-annually.
# - HVFHV files will now include 17 more columns (please see High Volume FHV Trips Dictionary for details). Additional columns will be added to the old files as well. The earliest date to include additional columns: February 2019.
# - Yellow trip data will now include 1 additional column (‘airport_fee’, please see Yellow Trips Dictionary for details). The additional column will be added to the old files as well. The earliest date to include the additional column: January 2011.
#
#
# **Download the data for January and February 2023**
#
# Dataset: https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page
#
#
# **Data Dictionaries and MetaData**
#
# - We'll use the same `NYC taxi dataset`, but instead of "Yellow Taxi Trip Records", we'll use `"Green Taxi Trip Records"`.
#
# > `Green Trips Data Dictionary`: https://www.nyc.gov/assets/tlc/downloads/pdf/data_dictionary_trip_records_green.pdf

# %% [markdown]
# **TASK**
#
# The goal of this homework is to familiarize users with workflow orchestration.
#
# Start with the orchestrate.py file in the 03-orchestration/3.4 folder
# of the course repo: https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/03-orchestration/3.4/orchestrate.py<br>
#
# Questions: https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/cohorts/2023/03-orchestration/homework.md
#
# - https://sagarthacker.com/posts/mlops/intro_workflow_orchestration.html
# - https://sagarthacker.com/posts/mlops/prefect-blocks.html
# - https://sagarthacker.com/posts/mlops/prefect-deployment.html
#
#
# **Table of Content**
#
#
# 1. Import Libraries and Ingest Data
#     - Q1. Human-readable name<br>
# 2. Recognizing and Understanding Data
#     - Q2. Cron<br>

# %% [markdown]
# <div style="letter-spacing:normal; opacity:1.;">
#   <h1 style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>1. Import Libraries & Ingest Data</strong></h1>
# </div>
#
# > ⚠️ Not Recommended conda `base` env, work on `venv`
#
# - https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf
#
# ```
# pip freeze > requirements.txt
# conda list -e > requirements.txt
#
# # new conda virtual environment
# conda create --name "prefect-ops" python=3.10 jupyter -y
# conda activate "prefect-ops"
#
# # install all package dependencies
# pip install -r requirements.txt
# conda install -c conda-forge --file=requirements.txt      # mostly not work
# conda install -c conda-forge pandas==2.0.2 -q -y
#
# # if The environment is inconsistent, try below
# conda update -n base -c defaults conda --force-reinstall
# conda install anaconda --force-reinstall
#
# ```
#
# **You must use the `--no-deps` option in the pip install command in order to avoid bundling dependencies into your conda-package.**
#
# If you run pip install without the `--no-deps` option, pip will often install dependencies in your conda recipe and those dependencies will become part of your package. This wastes space in the package and `increases the risk of file overlap`, file clobbering, and broken packages.
#
# There might be cases where you want to install a package directly from a local directory or a specific location, without relying on the package indexes. In such situations, you can use the `--no-index` option to tell pip not to look for the package in any indexes.
#
# ```
# - command1 & command2  # runs simultaneously
# - command1 ; command2  # runs sequentially
# - command1 && command2 # runs sequentially, runs command2 only if command1 succeeds
# - command1 || command2 # runs sequentially, runs command2 only if command1 fails
# ```

# %%
# # %%capture cap --no-stderr  # capture outputs  # cap.show()
# !cat /etc/os-release
# !grep -E -w 'VERSION|NAME|PRETTY_NAME' /etc/os-release

# %%
# check enviroment
# !conda env list
# !conda info -e
# !conda info | grep 'active env'

# %%
# %%writefile requirements.txt
# # To get started with MLflow you'll need to install the appropriate Python package.
#
# pandas==2.0.2
# orjson==3.9.1          # orjson is a fast, correct JSON library
# seaborn==0.12.2
#
# # ML Model packages
# scikit-learn==1.2.2
# xgboost==1.7.3
#
# # MLOPS packages
# mlflow==2.4.1
# wandb==0.15.4
# prefect==2.10.18
# prefect-email==0.2.2
# prefect-aws==0.3.4
#
# # Optionally
# black==23.3.0          # code style
#
# # ML Model packages
# hyperopt==0.2.7
#
# # for parquet file
# pyarrow==11.0.0
# fastparquet==2023.4.0
#
# # if new env
# # jupyter
# # ipykernel
# # ipywidgets
# Out:
# Overwriting requirements.txt

# %%
import os, sys, platform, IPython.display

# !{sys.executable} -m pip install -Uq -r requirements.txt  #  --no-deps --no-cache-dir --force-reinstall --no-index
# !jupyter nbextension enable --py widgetsnbextension

# IPython.display.clear_output()
print("Python  :", sys.version)
print("Platform:", platform.system(), platform.platform())
print("Actv Env:", os.environ['CONDA_DEFAULT_ENV'])
# Out:
# 2154.30s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 2171.40s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK
# Python  : 3.10.11 (main, May 16 2023, 00:28:57) [GCC 11.2.0]
# Platform: Linux Linux-5.15.90.1-microsoft-standard-WSL2-x86_64-with-glibc2.35
# Actv Env: prefect-ops

# %%
import os
# Get the current working directory
# current_dir = os.getcwd()

# Create a new directory for storing MLflow data
os.makedirs('./data', exist_ok=True)
os.makedirs('./pycode', exist_ok=True)
os.makedirs('./models', exist_ok=True)

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import scipy
from scipy.stats import stats

import sklearn
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error
import xgboost as xgb

import os
import wandb
import mlflow
import pickle
import pathlib
import argparse
from glob import glob
from tqdm import tqdm
tqdm._instances.clear()

from prefect import task, flow, Flow
from prefect.tasks import task_input_hash
from prefect.artifacts import create_markdown_artifact

# memory management performs garbage collection 
import gc
gc.collect()
# Out:
# 156

# %% [markdown]
# <div style="letter-spacing:normal; opacity:1.;">
#   <h1 style="text-align:center; background-color: lightsalmon; color: Jaguar; border-radius:10px; font-family:monospace; border-radius:20px;
#             line-height:1.4; font-size:32px; font-weight:bold; text-transform: uppercase; padding: 9px;">
#             <strong>2. Recognizing and Understanding Data</strong></h1>
# </div>

# %% [markdown]
# ## Ingest Data [wget](https://linuxways.net/centos/linux-wget-command-with-examples/) or [curl](https://daniel.haxx.se/blog/2020/09/10/store-the-curl-output-over-there/)

# %%
# "Green Taxi Trip Records" Download the data for January, February and March 2022
# !wget -q -N -P "./data" https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-01.parquet
# !wget -q -N -P "./data" https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-02.parquet
# !wget -q -N -P "./data" https://d37ci6vzurychx.cloudfront.net/trip-data/green_tripdata_2023-03.parquet

# %%
glob(f'./data/*.parquet')
# Out:
# []

# %% [markdown]
# ## Q1. Human-readable name
#
# You’d like to give the first task, `read_data` a nicely formatted name.
# How can you specify a task name?
#
# > Hint: look in the docs at https://docs.prefect.io or
# > check out the doc string in a code editor.
#
# - `@task(retries=3, retry_delay_seconds=2, name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task_name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task-name="Read taxi data")`
# - `@task(retries=3, retry_delay_seconds=2, task_name_function=lambda x: f"Read taxi data")`
#
# **How can you specify a task name?**
# - https://docs.prefect.io/2.10.13/concepts/tasks/
# - @task(retries=3, retry_delay_seconds=2, name="Read taxi data")

# %% [markdown]
# ## Q2. Cron
#
# Cron is a common scheduling specification for workflows.
#
# Using the flow in `orchestrate.py`, create a deployment.
# Schedule your deployment to run on the third day of every month at 9am UTC.
#
# **What’s the cron schedule for that?**
#
# components of the cron expression:
#
# - The first field, 0, represents the minute of the hour. In this case, it is set to 0, meaning the deployment will run at the start of the hour.
# - The second field, 9, represents the hour of the day. It is set to 9, indicating that the deployment will run at 9am.
# - The third field, 3, represents the day of the month. This field is set to 3, which means the deployment will run specifically on the third day of each month.
# - The fourth field, *, represents the month. It is set to *, indicating that the deployment will run every month.
# - The fifth field, *, represents the day of the week. It is also set to *, meaning that the deployment will run regardless of the day of the week.
#
# Therefore, the cron schedule for running the deployment on the third day of every month at 9am UTC is:
# - `0 9 3 * *`

# %% [markdown]
# ## Q3. RMSE
#
# Download the January 2023 Green Taxi data and use it for your training data.
# Download the February 2023 Green Taxi data and use it for your validation data.
#
# Make sure you upload the data to GitHub so it is available for your deployment.
#
# Create a custom flow run of your deployment from the UI. Choose Custom
# Run for the flow and enter the file path as a string on the JSON tab under Parameters.
#
# Make sure you have a worker running and polling the correct work pool.
#
# View the results in the UI.
#
# **What’s the final RMSE to five decimal places?**
#
# mlflow-remote code:
# - https://www.mlflow.org/docs/latest/tracking.html#how-runs-and-artifacts-are-recorded
# - Run Terminal:
#
# ```
# # if using port 5000 or use another port
# kill $(lsof -ti :5000)   # clear port 5000
#
# # after set_experiment (building mlflow.db), go to bash cd path to (mlruns ant mlflow.db) folder
# mlflow ui \
#     --backend-store-uri sqlite:///mlflow.db \
#     --default-artifact-root  file:mlruns \
#     --host localhost --port 5000
# ```
#
# <br>

# %% [markdown]
# ![prefec](https://i.imgur.com/Hb03uv3.png)

# %% [markdown]
# Check Data
# ```sh
# git remote -v
# ```
#
# **Step 1: Create a Project in a New Directory**
#
# - .prefectignore File any Github-Gitlab
# ```sh
# prefect init
# prefect project init # deprecated
# ```
#
# **Step 2: Add an @flow decorator to your code's entrypoint function, give it a name and Save it to the New Directory**
#
# - like orchestrate.py
#
#
# **Step 3: Orchestration Enviroment (Server Runs or Prefect Cloud)**
#
# - Start the Prefect server locally
#
# Create another window and activate your conda environment. Start the Prefect API server locally with
# Start and Open Source Prefect Server
# ```sh
# prefect server start
# ```
#
# - Or Login to Prefect Cloud
# ```sh
# prefect cloud login
# ```
#
# **Step 4: Execution Enviroment (Flows Run)**
#
# - Start a worker that polls your work pool
# ```sh
# prefect worker start --pool 'zoom_mlops_pool'
# prefect worker start -p "zoom_mlops_pool" -t process
# ```
#
# **Step 5: Deploy your Flow**
#
# - Start a worker that polls your work pool
# ```sh
# prefect deploy ls
# prefect deploy "./pycode/orchestrate.py:main_flow" -n "zoom_mlops_deployment" -p "zoom_mlops_pool"
# prefect deploy --all  # or
# ```
#
# **Step 6: Start a run of the deployed flow from the CLI...**
#
# - Start a worker that polls your work pool
# ```sh
# prefect deployment ls
# prefect deployment run "Hello/zoom_mlops_deployment"
# ```
#
# **Check...**
#
# - another pools
# ```sh
# prefect block ls
# prefect block type ls
# ```
#
# ```sh
# prefect block register -m prefect_aws
# ```

# %%
# %%writefile ./pycode/orchestrate.py

# Source: https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/03-orchestration/3.4/orchestrate.py

import os
import click
import pickle
import pathlib
import argparse
import requests
import urllib.request
from glob import glob
from datetime import date
from datetime import timedelta

import pandas as pd
import numpy as np
import scipy
import sklearn
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error
import xgboost as xgb

import mlflow
from prefect import task, flow, Flow
from prefect.tasks import task_input_hash
from prefect.artifacts import create_markdown_artifact

# from prefect_aws import S3Bucket
# from prefect_email import EmailServerCredentials, email_send_message

import warnings
# Ignore all warnings
# warnings.filterwarnings("ignore")
# Filter the specific warning message, MLflow autologging encountered a warning
# warnings.filterwarnings("ignore", category=UserWarning, module="setuptools")
warnings.filterwarnings("ignore", category=UserWarning, message="Setuptools is replacing distutils.")


@task(name="Fetch Data", cache_key_fn=task_input_hash, cache_expiration=timedelta(days=1),
      retries=3, log_prints=True, )
def fetch_data(raw_data_path: str, year: int, month: int, color: str) -> None:
    """Fetches data from the NYC Taxi dataset and saves it locally"""
    os.makedirs(raw_data_path, exist_ok=True)  

    # Download the data from the NYC Taxi dataset
    url      = f'https://d37ci6vzurychx.cloudfront.net/trip-data/{color}_tripdata_{year}-{month:0>2}.parquet'
    filename = os.path.join(raw_data_path, f'{color}_tripdata_{year}-{month:0>2}.parquet')
    # urllib.request.urlretrieve(url, filename)
    # os.system(f"wget -q -N -P {raw_data_path} {url}")
    
    response = requests.get(url)
    with open(filename, "wb") as f:
        f.write(response.content)
    return None
    
    
@task(name="Read Taxi Data", retries=3, retry_delay_seconds=2, log_prints=None)
def read_data(filename: str) -> pd.DataFrame:
    """Read data into DataFrame"""
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime  = pd.to_datetime(df.lpep_pickup_datetime)

    df["duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration    = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical     = ["PULocationID", "DOLocationID"]
    df[categorical] = df[categorical].astype(str)

    return df


@task(name="Add Features Taxi Data", log_prints=True)
def add_features(
    df_train: pd.DataFrame, df_val: pd.DataFrame, df_test: pd.DataFrame
) -> tuple(
    [
        scipy.sparse._csr.csr_matrix,
        scipy.sparse._csr.csr_matrix,
        np.ndarray,
        np.ndarray,
        sklearn.feature_extraction.DictVectorizer,
    ]
):
    """Add features to the model"""
    df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
    df_val["PU_DO"]   = df_val["PULocationID"]   + "_" + df_val["DOLocationID"]
    df_test["PU_DO"]  = df_test["PULocationID"]  + "_" + df_test["DOLocationID"]

    categorical = ["PU_DO"]  #'PULocationID', 'DOLocationID']
    numerical   = ["trip_distance"]

    dv = DictVectorizer()

    train_dicts = df_train[categorical + numerical].to_dict(orient="records")
    X_train     = dv.fit_transform(train_dicts)
    y_train     = df_train["duration"].values

    val_dicts   = df_val[categorical + numerical].to_dict(orient="records")
    X_val       = dv.transform(val_dicts)
    y_val       = df_val["duration"].values
    
    test_dicts  = df_test[categorical + numerical].to_dict(orient="records")
    X_test      = dv.transform(test_dicts)
    y_test      = df_test["duration"].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), dv


@task(name="Train Best Model", log_prints=True)
def train_best_model(
    X_train  : scipy.sparse._csr.csr_matrix,
    X_val    : scipy.sparse._csr.csr_matrix,
    y_train  : np.ndarray,
    y_val    : np.ndarray,
    dv       : sklearn.feature_extraction.DictVectorizer,
    dest_path: str,
) -> None:
    """train a model with best hyperparams and write everything out"""        
    # Load train and test Data
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    # before your training code to enable automatic logging of sklearn metrics, params, and models
    # mlflow.xgboost.autolog()
    
    with mlflow.start_run():
        # Optional: Set some information about Model
        mlflow.set_tag("developer", "muce")
        mlflow.set_tag("algorithm", "Machine Learning")
        mlflow.set_tag("train-data-path", f'./data/green_tripdata_2023-01.parquet')
        mlflow.set_tag("valid-data-path", f'./data/green_tripdata_2023-02.parquet')
        mlflow.set_tag("test-data-path",  f'./data/green_tripdata_2023-03.parquet')

        # Set Model params information
        best_params = {
            "learning_rate": 0.09585355369315604,
            "max_depth": 30,
            "min_child_weight": 1.060597050922164,
#             'objective': 'reg:squarederror',          # deprecated  "reg:linear"
            'objective': "reg:linear",
            "reg_alpha": 0.018060244040060163,
            "reg_lambda": 0.011658731377413597,
            "seed": 42,
        }
        mlflow.log_params(best_params)

        # Build Model   
        booster = xgb.train(
            params               = best_params,
            dtrain               = train,
            num_boost_round      = 100,
            evals                = [(valid, "validation")],
            early_stopping_rounds=20,
        )   
        
        # Set Model Evaluation Metric
        y_pred = booster.predict(valid)
        rmse   = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)       

        # Log Model two options
        # Option1: Just log model
        mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")        
        
        # Option 2: save Model, Optional: Preprocessor or Pipeline         
        # Create dest_path folder unless it already exists
        # pathlib.Path(dest_path).mkdir(exist_ok=True) 
        os.makedirs(dest_path, exist_ok=True)       
        local_file = os.path.join(dest_path, "preprocessor.b")
        with open(local_file, "wb") as f_out:
            pickle.dump(dv, f_out)
            
        # whole proccess like pickle, saved Model, Optional: Preprocessor or Pipeline
        mlflow.log_artifact(local_path = local_file, artifact_path="preprocessor")        
        
        # print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
    return None


@flow(name="Subflow Download Data", log_prints=True)
def download_data(raw_data_path: str, years: list, months: list, colors: list):
    # Download the data from the NYC Taxi dataset
    for year in years:
        for month in months:
            for color in colors:
                fetch_data(raw_data_path, year, month, color)
                

@click.command()
@click.option(
    "--raw_data_path",
    default="./data",
    help="Location where the raw NYC taxi trip data was saved"
)
@click.option(
    "--dest_path",
    default="./models",
    help="Location where the resulting model files will be saved"
)
@click.option(
    "--years",
    default="2023",
    help="Years where the raw NYC taxi trip data was saved (space-separated)"
)
@click.option(
    "--months",
    default="1 2 3",
    help="Months where the raw NYC taxi trip data was saved (space-separated)"
)
@click.option(
    "--colors",
    default="green yellow",
    help="Colors where the raw NYC taxi trip data was saved"
)
@flow(name="Main Flow")
def main_flow(raw_data_path: str, dest_path: str, years: str, months: str, colors: str) -> None:
    """The main training pipeline"""
    # MLflow settings
    # Build or Connect Database Offline
    mlflow.set_tracking_uri("sqlite:///mlflow.db")
    # Build or Connect mlflow experiment
    mlflow.set_experiment("nyc-taxi-experiment")
    
    # Download data    
    years  = [int(year) for year in years.split()]
    months = [int(month) for month in months.split()]
    colors = colors.split()[:1]
    download_data(raw_data_path, years, months, colors)
    print(sorted(glob(f'./data/*')))
    
    # list parquet files
    # print(sorted(glob(f'{raw_data_path}/green*.parquet')))
    train_path, val_path, test_path = sorted(glob(f'{raw_data_path}/*.parquet'))

    # Read parquet files
    df_train = read_data(train_path)
    df_val   = read_data(val_path)
    df_test  = read_data(test_path)
    # print(df_train.shape, df_val.shape, df_test.shape, )

    # Transform
    (X_train, y_train), (X_val, y_val), (X_test, y_test), dv = add_features(df_train, df_val, df_test)

    # Train
    train_best_model(X_train, X_val, y_train, y_val, dv, dest_path)


if __name__ == "__main__":
    main_flow()
# Out:
# Overwriting ./pycode/orchestrate.py

# %%
# raw_data_path
# DATA_PATH = f"./data"

# !python ./pycode/orchestrate.py
# Out:
# 5033.37s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 11:31:00.842 | INFO    | prefect.engine - Created flow run 'persimmon-heron' for flow 'Main Flow'
# 11:31:00.845 | INFO    | Flow run 'persimmon-heron' - View at http://127.0.0.1:4200/flow-runs/flow-run/4148a7db-e64a-4671-a1fe-6df89387ff87
# 2023/07/03 11:31:01 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/07/03 11:31:01 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 11:31:02.020 | INFO    | Flow run 'persimmon-heron' - Created subflow run 'ubiquitous-coua' for flow 'Subflow Download Data'
# 11:31:02.022 | INFO    | Flow run 'ubiquitous-coua' - View at http://127.0.0.1:4200/flow-runs/flow-run/8bb6f255-5959-49c0-9f99-a1ffaa35f0b3
# 11:31:02.337 | INFO    | Flow run 'ubiquitous-coua' - Created task run 'Fetch Data-0' for task 'Fetch Data'
# 11:31:02.339 | INFO    | Flow run 'ubiquitous-coua' - Executing 'Fetch Data-0' immediately...
# 11:31:03.949 | INFO    | Task run 'Fetch Data-0' - Finished in state Completed()
# 11:31:04.011 | INFO    | Flow run 'ubiquitous-coua' - Created task run 'Fetch Data-1' for task 'Fetch Data'
# 11:31:04.014 | INFO    | Flow run 'ubiquitous-coua' - Executing 'Fetch Data-1' immediately...
# 11:31:05.604 | INFO    | Task run 'Fetch Data-1' - Finished in state Completed()
# 11:31:05.668 | INFO    | Flow run 'ubiquitous-coua' - Created task run 'Fetch Data-2' for task 'Fetch Data'
# 11:31:05.669 | INFO    | Flow run 'ubiquitous-coua' - Executing 'Fetch Data-2' immediately...
# 11:31:06.547 | INFO    | Task run 'Fetch Data-2' - Finished in state Completed()
# 11:31:06.678 | INFO    | Flow run 'ubiquitous-coua' - Finished in state Completed('All states completed.')
# ['./data/green_tripdata_2023-01.parquet', './data/green_tripdata_2023-02.parquet', './data/green_tripdata_2023-03.parquet']
# 11:31:06.756 | INFO    | Flow run 'persimmon-heron' - Created task run 'Read Taxi Data-0' for task 'Read Taxi Data'
# 11:31:06.757 | INFO    | Flow run 'persimmon-heron' - Executing 'Read Taxi Data-0' immediately...
# 11:31:07.950 | INFO    | Task run 'Read Taxi Data-0' - Finished in state Completed()
# 11:31:08.037 | INFO    | Flow run 'persimmon-heron' - Created task run 'Read Taxi Data-1' for task 'Read Taxi Data'
# 11:31:08.038 | INFO    | Flow run 'persimmon-heron' - Executing 'Read Taxi Data-1' immediately...
# 11:31:08.754 | INFO    | Task run 'Read Taxi Data-1' - Finished in state Completed()
# 11:31:08.810 | INFO    | Flow run 'persimmon-heron' - Created task run 'Read Taxi Data-2' for task 'Read Taxi Data'
# 11:31:08.812 | INFO    | Flow run 'persimmon-heron' - Executing 'Read Taxi Data-2' immediately...
# 11:31:09.563 | INFO    | Task run 'Read Taxi Data-2' - Finished in state Completed()
# 11:31:09.685 | INFO    | Flow run 'persimmon-heron' - Created task run 'Add Features Taxi Data-0' for task 'Add Features Taxi Data'
# 11:31:09.687 | INFO    | Flow run 'persimmon-heron' - Executing 'Add Features Taxi Data-0' immediately...
# 11:31:18.415 | INFO    | Task run 'Add Features Taxi Data-0' - Finished in state Completed()
# 11:31:18.542 | INFO    | Flow run 'persimmon-heron' - Created task run 'Train Best Model-0' for task 'Train Best Model'
# 11:31:18.544 | INFO    | Flow run 'persimmon-heron' - Executing 'Train Best Model-0' immediately...
# [11:31:21] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# 11:31:23.941 | INFO    | Task run 'Train Best Model-0' - [0]    validation-rmse:15.01627
# 11:31:25.162 | INFO    | Task run 'Train Best Model-0' - [1]    validation-rmse:13.77591
# 11:31:26.579 | INFO    | Task run 'Train Best Model-0' - [2]    validation-rmse:12.66953
# 11:31:28.224 | INFO    | Task run 'Train Best Model-0' - [3]    validation-rmse:11.68972
# 11:31:29.054 | INFO    | Task run 'Train Best Model-0' - [4]    validation-rmse:10.81927
# 11:31:29.319 | INFO    | Task run 'Train Best Model-0' - [5]    validation-rmse:10.05352
# 11:31:29.612 | INFO    | Task run 'Train Best Model-0' - [6]    validation-rmse:9.37638
# 11:31:29.843 | INFO    | Task run 'Train Best Model-0' - [7]    validation-rmse:8.78514
# 11:31:30.159 | INFO    | Task run 'Train Best Model-0' - [8]    validation-rmse:8.26684
# 11:31:30.412 | INFO    | Task run 'Train Best Model-0' - [9]    validation-rmse:7.81889
# 11:31:30.784 | INFO    | Task run 'Train Best Model-0' - [10]   validation-rmse:7.42994
# 11:31:31.262 | INFO    | Task run 'Train Best Model-0' - [11]   validation-rmse:7.09348
# 11:31:31.518 | INFO    | Task run 'Train Best Model-0' - [12]   validation-rmse:6.80836
# 11:31:31.802 | INFO    | Task run 'Train Best Model-0' - [13]   validation-rmse:6.56211
# 11:31:32.200 | INFO    | Task run 'Train Best Model-0' - [14]   validation-rmse:6.35332
# 11:31:32.391 | INFO    | Task run 'Train Best Model-0' - [15]   validation-rmse:6.17838
# 11:31:32.705 | INFO    | Task run 'Train Best Model-0' - [16]   validation-rmse:6.02763
# 11:31:33.689 | INFO    | Task run 'Train Best Model-0' - [17]   validation-rmse:5.90232
# 11:31:34.869 | INFO    | Task run 'Train Best Model-0' - [18]   validation-rmse:5.79691
# 11:31:35.326 | INFO    | Task run 'Train Best Model-0' - [19]   validation-rmse:5.70817
# 11:31:35.506 | INFO    | Task run 'Train Best Model-0' - [20]   validation-rmse:5.63182
# 11:31:35.790 | INFO    | Task run 'Train Best Model-0' - [21]   validation-rmse:5.56852
# 11:31:36.340 | INFO    | Task run 'Train Best Model-0' - [22]   validation-rmse:5.51520
# 11:31:36.514 | INFO    | Task run 'Train Best Model-0' - [23]   validation-rmse:5.47115
# 11:31:36.770 | INFO    | Task run 'Train Best Model-0' - [24]   validation-rmse:5.43421
# 11:31:36.965 | INFO    | Task run 'Train Best Model-0' - [25]   validation-rmse:5.40206
# 11:31:37.301 | INFO    | Task run 'Train Best Model-0' - [26]   validation-rmse:5.37653
# 11:31:37.442 | INFO    | Task run 'Train Best Model-0' - [27]   validation-rmse:5.35308
# 11:31:37.730 | INFO    | Task run 'Train Best Model-0' - [28]   validation-rmse:5.33437
# 11:31:37.932 | INFO    | Task run 'Train Best Model-0' - [29]   validation-rmse:5.31842
# 11:31:38.247 | INFO    | Task run 'Train Best Model-0' - [30]   validation-rmse:5.30434
# 11:31:38.371 | INFO    | Task run 'Train Best Model-0' - [31]   validation-rmse:5.29293
# 11:31:38.627 | INFO    | Task run 'Train Best Model-0' - [32]   validation-rmse:5.28270
# 11:31:38.762 | INFO    | Task run 'Train Best Model-0' - [33]   validation-rmse:5.27307
# 11:31:38.900 | INFO    | Task run 'Train Best Model-0' - [34]   validation-rmse:5.26638
# 11:31:39.037 | INFO    | Task run 'Train Best Model-0' - [35]   validation-rmse:5.26043
# 11:31:39.276 | INFO    | Task run 'Train Best Model-0' - [36]   validation-rmse:5.25512
# 11:31:39.464 | INFO    | Task run 'Train Best Model-0' - [37]   validation-rmse:5.25088
# 11:31:39.619 | INFO    | Task run 'Train Best Model-0' - [38]   validation-rmse:5.24664
# 11:31:39.847 | INFO    | Task run 'Train Best Model-0' - [39]   validation-rmse:5.24209
# 11:31:40.106 | INFO    | Task run 'Train Best Model-0' - [40]   validation-rmse:5.23909
# 11:31:40.429 | INFO    | Task run 'Train Best Model-0' - [41]   validation-rmse:5.23607
# 11:31:40.575 | INFO    | Task run 'Train Best Model-0' - [42]   validation-rmse:5.23344
# 11:31:40.674 | INFO    | Task run 'Train Best Model-0' - [43]   validation-rmse:5.23200
# 11:31:41.307 | INFO    | Task run 'Train Best Model-0' - [44]   validation-rmse:5.23097
# 11:31:41.451 | INFO    | Task run 'Train Best Model-0' - [45]   validation-rmse:5.22865
# 11:31:41.588 | INFO    | Task run 'Train Best Model-0' - [46]   validation-rmse:5.22775
# 11:31:41.714 | INFO    | Task run 'Train Best Model-0' - [47]   validation-rmse:5.22687
# 11:31:41.855 | INFO    | Task run 'Train Best Model-0' - [48]   validation-rmse:5.22582
# 11:31:42.008 | INFO    | Task run 'Train Best Model-0' - [49]   validation-rmse:5.22487
# 11:31:42.240 | INFO    | Task run 'Train Best Model-0' - [50]   validation-rmse:5.22442
# 11:31:42.372 | INFO    | Task run 'Train Best Model-0' - [51]   validation-rmse:5.22332
# 11:31:42.587 | INFO    | Task run 'Train Best Model-0' - [52]   validation-rmse:5.22236
# 11:31:42.710 | INFO    | Task run 'Train Best Model-0' - [53]   validation-rmse:5.22142
# 11:31:42.816 | INFO    | Task run 'Train Best Model-0' - [54]   validation-rmse:5.22022
# 11:31:42.949 | INFO    | Task run 'Train Best Model-0' - [55]   validation-rmse:5.21987
# 11:31:43.066 | INFO    | Task run 'Train Best Model-0' - [56]   validation-rmse:5.21908
# 11:31:43.238 | INFO    | Task run 'Train Best Model-0' - [57]   validation-rmse:5.21873
# 11:31:43.536 | INFO    | Task run 'Train Best Model-0' - [58]   validation-rmse:5.21820
# 11:31:43.843 | INFO    | Task run 'Train Best Model-0' - [59]   validation-rmse:5.21787
# 11:31:43.964 | INFO    | Task run 'Train Best Model-0' - [60]   validation-rmse:5.21702
# 11:31:44.747 | INFO    | Task run 'Train Best Model-0' - [61]   validation-rmse:5.21632
# 11:31:45.288 | INFO    | Task run 'Train Best Model-0' - [62]   validation-rmse:5.21571
# 11:31:45.453 | INFO    | Task run 'Train Best Model-0' - [63]   validation-rmse:5.21404
# 11:31:45.571 | INFO    | Task run 'Train Best Model-0' - [64]   validation-rmse:5.21348
# 11:31:46.402 | INFO    | Task run 'Train Best Model-0' - [65]   validation-rmse:5.21290
# 11:31:47.272 | INFO    | Task run 'Train Best Model-0' - [66]   validation-rmse:5.21262
# 11:31:47.504 | INFO    | Task run 'Train Best Model-0' - [67]   validation-rmse:5.21181
# 11:31:47.636 | INFO    | Task run 'Train Best Model-0' - [68]   validation-rmse:5.21179
# 11:31:47.801 | INFO    | Task run 'Train Best Model-0' - [69]   validation-rmse:5.21113
# 11:31:47.909 | INFO    | Task run 'Train Best Model-0' - [70]   validation-rmse:5.21051
# 11:31:48.037 | INFO    | Task run 'Train Best Model-0' - [71]   validation-rmse:5.21000
# 11:31:48.163 | INFO    | Task run 'Train Best Model-0' - [72]   validation-rmse:5.20944
# 11:31:48.363 | INFO    | Task run 'Train Best Model-0' - [73]   validation-rmse:5.20928
# 11:31:48.498 | INFO    | Task run 'Train Best Model-0' - [74]   validation-rmse:5.20890
# 11:31:48.658 | INFO    | Task run 'Train Best Model-0' - [75]   validation-rmse:5.20840
# 11:31:48.977 | INFO    | Task run 'Train Best Model-0' - [76]   validation-rmse:5.20723
# 11:31:49.216 | INFO    | Task run 'Train Best Model-0' - [77]   validation-rmse:5.20677
# 11:31:49.631 | INFO    | Task run 'Train Best Model-0' - [78]   validation-rmse:5.20653
# 11:31:49.819 | INFO    | Task run 'Train Best Model-0' - [79]   validation-rmse:5.20608
# 11:31:50.702 | INFO    | Task run 'Train Best Model-0' - [80]   validation-rmse:5.20599
# 11:31:51.799 | INFO    | Task run 'Train Best Model-0' - [81]   validation-rmse:5.20558
# 11:31:52.027 | INFO    | Task run 'Train Best Model-0' - [82]   validation-rmse:5.20516
# 11:31:53.058 | INFO    | Task run 'Train Best Model-0' - [83]   validation-rmse:5.20428
# 11:31:53.431 | INFO    | Task run 'Train Best Model-0' - [84]   validation-rmse:5.20377
# 11:31:53.532 | INFO    | Task run 'Train Best Model-0' - [85]   validation-rmse:5.20323
# 11:31:53.671 | INFO    | Task run 'Train Best Model-0' - [86]   validation-rmse:5.20281
# 11:31:53.773 | INFO    | Task run 'Train Best Model-0' - [87]   validation-rmse:5.20294
# 11:31:53.865 | INFO    | Task run 'Train Best Model-0' - [88]   validation-rmse:5.20271
# 11:31:53.980 | INFO    | Task run 'Train Best Model-0' - [89]   validation-rmse:5.20245
# 11:31:54.113 | INFO    | Task run 'Train Best Model-0' - [90]   validation-rmse:5.20201
# 11:31:54.208 | INFO    | Task run 'Train Best Model-0' - [91]   validation-rmse:5.20186
# 11:31:54.393 | INFO    | Task run 'Train Best Model-0' - [92]   validation-rmse:5.20146
# 11:31:54.513 | INFO    | Task run 'Train Best Model-0' - [93]   validation-rmse:5.20144
# 11:31:54.628 | INFO    | Task run 'Train Best Model-0' - [94]   validation-rmse:5.20096
# 11:31:54.728 | INFO    | Task run 'Train Best Model-0' - [95]   validation-rmse:5.20087
# 11:31:54.828 | INFO    | Task run 'Train Best Model-0' - [96]   validation-rmse:5.20016
# 11:31:54.923 | INFO    | Task run 'Train Best Model-0' - [97]   validation-rmse:5.19983
# 11:31:55.095 | INFO    | Task run 'Train Best Model-0' - [98]   validation-rmse:5.19931
# 11:31:55.200 | INFO    | Task run 'Train Best Model-0' - [99]   validation-rmse:5.19931
# 11:32:44.387 | INFO    | Task run 'Train Best Model-0' - Finished in state Completed()
# 11:32:44.745 | INFO    | Flow run 'persimmon-heron' - Finished in state Completed('All states completed.')

# %% [markdown]
# ## Q4. RMSE (Markdown Artifact)
#
# Download the February 2023 Green Taxi data and use it for your training data.
# Download the March 2023 Green Taxi data and use it for your validation data.
#
# Create a Prefect Markdown artifact that displays the RMSE for the validation data.
# Create a deployment and run it.
#
# **What’s the RMSE in the artifact to two decimal places ?**

# %%
# %%writefile ./pycode/create_s3_bucket_block.py

from time import sleep
from prefect_aws import S3Bucket, AwsCredentials


def create_aws_creds_block():
    my_aws_creds_obj = AwsCredentials(
        aws_access_key_id="123abc", aws_secret_access_key="abc123"
    )
    my_aws_creds_obj.save(name="my-aws-creds", overwrite=True)


def create_s3_bucket_block():
    aws_creds = AwsCredentials.load("my-aws-creds")
    my_s3_bucket_obj = S3Bucket(
        bucket_name="my-first-bucket-abc", credentials=aws_creds
    )
    my_s3_bucket_obj.save(name="s3-bucket-example", overwrite=True)


if __name__ == "__main__":
    create_aws_creds_block()
    sleep(5)
    create_s3_bucket_block()

# %%
# %%writefile ./pycode/orchestrate.py

# Source: https://github.com/DataTalksClub/mlops-zoomcamp/blob/main/03-orchestration/3.4/orchestrate.py

import os
import click
import pickle
import pathlib
import argparse
import requests
import urllib.request
from glob import glob
from datetime import date
from datetime import timedelta

import pandas as pd
import numpy as np
import scipy
import sklearn
from sklearn.feature_extraction import DictVectorizer
from sklearn.metrics import mean_squared_error
import xgboost as xgb

import mlflow
import prefect
from prefect import task, flow
from prefect.tasks import task_input_hash
from prefect.artifacts import create_markdown_artifact

# from prefect_aws import S3Bucket
# from prefect_email import EmailServerCredentials, email_send_message

import warnings
# Ignore all warnings
# warnings.filterwarnings("ignore")
# Filter the specific warning message, MLflow autologging encountered a warning
# warnings.filterwarnings("ignore", category=UserWarning, module="setuptools")
warnings.filterwarnings("ignore", category=UserWarning, message="Setuptools is replacing distutils.")


@task(name="Fetch Data", cache_key_fn=task_input_hash, cache_expiration=timedelta(days=1),
      retries=3, log_prints=True, )
def fetch_data(raw_data_path: str, year: int, month: int, color: str) -> None:
    """Fetches data from the NYC Taxi dataset and saves it locally"""
    os.makedirs(raw_data_path, exist_ok=True)  

    # Download the data from the NYC Taxi dataset
    url      = f'https://d37ci6vzurychx.cloudfront.net/trip-data/{color}_tripdata_{year}-{month:0>2}.parquet'
    filename = os.path.join(raw_data_path, f'{color}_tripdata_{year}-{month:0>2}.parquet')
    # urllib.request.urlretrieve(url, filename)
    # os.system(f"wget -q -N -P {raw_data_path} {url}")
    
    response = requests.get(url)
    with open(filename, "wb") as f:
        f.write(response.content)
    return None
    
    
@task(name="Read Taxi Data", retries=3, retry_delay_seconds=2, log_prints=None)
def read_data(filename: str) -> pd.DataFrame:
    """Read data into DataFrame"""
    df = pd.read_parquet(filename)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime  = pd.to_datetime(df.lpep_pickup_datetime)

    df["duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration    = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical     = ["PULocationID", "DOLocationID"]
    df[categorical] = df[categorical].astype(str)

    return df


@task(name="Add Features Taxi Data", log_prints=True)
def add_features(
    df_train: pd.DataFrame, df_val: pd.DataFrame, df_test: pd.DataFrame
) -> tuple(
    [
        scipy.sparse._csr.csr_matrix,
        scipy.sparse._csr.csr_matrix,
        np.ndarray,
        np.ndarray,
        sklearn.feature_extraction.DictVectorizer,
    ]
):
    """Add features to the model"""
    df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
    df_val["PU_DO"]   = df_val["PULocationID"]   + "_" + df_val["DOLocationID"]
    df_test["PU_DO"]  = df_test["PULocationID"]  + "_" + df_test["DOLocationID"]

    categorical = ["PU_DO"]  #'PULocationID', 'DOLocationID']
    numerical   = ["trip_distance"]

    dv = DictVectorizer()

    train_dicts = df_train[categorical + numerical].to_dict(orient="records")
    X_train     = dv.fit_transform(train_dicts)
    y_train     = df_train["duration"].values

    val_dicts   = df_val[categorical + numerical].to_dict(orient="records")
    X_val       = dv.transform(val_dicts)
    y_val       = df_val["duration"].values
    
    test_dicts  = df_test[categorical + numerical].to_dict(orient="records")
    X_test      = dv.transform(test_dicts)
    y_test      = df_test["duration"].values

    return (X_train, y_train), (X_val, y_val), (X_test, y_test), dv


@task(name="Train Best Model", log_prints=True)
def train_best_model(
    X_train  : scipy.sparse._csr.csr_matrix,
    X_val    : scipy.sparse._csr.csr_matrix,
    y_train  : np.ndarray,
    y_val    : np.ndarray,
    dv       : sklearn.feature_extraction.DictVectorizer,
    dest_path: str,
) -> None:
    """train a model with best hyperparams and write everything out"""        
    # Load train and test Data
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    # before your training code to enable automatic logging of sklearn metrics, params, and models
    # mlflow.xgboost.autolog()
    
    with mlflow.start_run():
        # Optional: Set some information about Model
        mlflow.set_tag("developer", "muce")
        mlflow.set_tag("algorithm", "Machine Learning")
        mlflow.set_tag("train-data-path", f'./data/green_tripdata_2023-01.parquet')
        mlflow.set_tag("valid-data-path", f'./data/green_tripdata_2023-02.parquet')
        mlflow.set_tag("test-data-path",  f'./data/green_tripdata_2023-03.parquet')

        # Set Model params information
        best_params = {
            "learning_rate": 0.09585355369315604,
            "max_depth": 30,
            "min_child_weight": 1.060597050922164,
#             'objective': 'reg:squarederror',          # deprecated  "reg:linear"
            'objective': "reg:linear",
            "reg_alpha": 0.018060244040060163,
            "reg_lambda": 0.011658731377413597,
            "seed": 42,
        }
        mlflow.log_params(best_params)

        # Build Model   
        booster = xgb.train(
            params               = best_params,
            dtrain               = train,
            num_boost_round      = 100,
            evals                = [(valid, "validation")],
            early_stopping_rounds=20,
        )   
        
        # Set Model Evaluation Metric
        y_pred = booster.predict(valid)
        rmse   = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)       

        # Log Model two options
        # Option1: Just log model
        mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")        
        
        # Option 2: save Model, Optional: Preprocessor or Pipeline         
        # Create dest_path folder unless it already exists
        # pathlib.Path(dest_path).mkdir(exist_ok=True) 
        os.makedirs(dest_path, exist_ok=True)       
        local_file = os.path.join(dest_path, "preprocessor.b")
        with open(local_file, "wb") as f_out:
            pickle.dump(dv, f_out)
            
        # whole proccess like pickle, saved Model, Optional: Preprocessor or Pipeline
        mlflow.log_artifact(local_path = local_file, artifact_path="preprocessor")        
        
        # print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")

        # Create markdown artifact with RMSE value
        markdown__rmse_report = f"""# RMSE Report

        ## Summary

        Duration Prediction 

        ## RMSE XGBoost Model

        | Region    | RMSE |
        |:----------|-------:|
        | {date.today()} | {rmse:.2f} |
        """

        create_markdown_artifact(
            key="duration-model-report", 
            markdown=markdown__rmse_report,
            description="RMSE for Validation Data Report",
        )
    return None


@flow(name="Subflow Download Data", log_prints=True)
def download_data(raw_data_path: str, years: list, months: list, colors: list):
    # Download the data from the NYC Taxi dataset
    for year in years:
        for month in months:
            for color in colors:
                fetch_data(raw_data_path, year, month, color)


# @flow(name="Email Server Crenditals", log_prints=True)
# def example_email_send_message_flow(email_addresses: list[str]):
#     email_server_credentials = EmailServerCredentials.load("email-server-credentials")
    
#     for email_address in email_addresses:
#         subject = email_send_message.with_options(name=f"email {email_address}").submit(
#             email_server_credentials=email_server_credentials,
#             subject="Example Flow Notification using Gmail",
#             msg="This proves email_send_message works!",
#             email_to=email_address,
#         )
                

@flow(name="Main Flow")
@click.command()
@click.option(
    "--raw_data_path",
    default="./data",
    help="Location where the raw NYC taxi trip data was saved"
)
@click.option(
    "--dest_path",
    default="./models",
    help="Location where the resulting model files will be saved"
)
@click.option(
    "--years",
    default="2023",
    help="Years where the raw NYC taxi trip data was saved (space-separated)"
)
@click.option(
    "--months",
    default="1 2 3 4",
    help="Months where the raw NYC taxi trip data was saved (space-separated)"
)
@click.option(
    "--colors",
    default="green yellow",
    help="Colors where the raw NYC taxi trip data was saved"
)
def main_flow(raw_data_path: str, dest_path: str, years: str, months: str, colors: str) -> None:
    """The main training pipeline"""
    # MLflow settings
    # Build or Connect Database Offline
    mlflow.set_tracking_uri("sqlite:///mlflow.db")
    # Build or Connect mlflow experiment
    mlflow.set_experiment("nyc-taxi-experiment")
    
    # Download data    
    years  = [int(year) for year in years.split()]
    months = [int(month) for month in months.split()]
    colors = colors.split()[:1]
    download_data(raw_data_path, years, months, colors)
    # print(glob(f'*'))
    
    # # Download the data from AWS S3 Bucket
    # s3_bucket_block = S3Bucket.load("s3-bucket-block")
    # s3_bucket_block.download_folder_to_path(from_folder="data", to_folder="data")
    
    # list parquet files
    # print(sorted(glob(f'{raw_data_path}/green*.parquet')))
    train_path, val_path, test_path = sorted(glob(f'{raw_data_path}/*.parquet'))[-3::]

    # Read parquet files
    df_train = read_data(train_path)
    df_val   = read_data(val_path)
    df_test  = read_data(test_path)
    # print(df_train.shape, df_val.shape, df_test.shape, )

    # Transform
    (X_train, y_train), (X_val, y_val), (X_test, y_test), dv = add_features(df_train, df_val, df_test)

    # Train
    train_best_model(X_train, X_val, y_train, y_val, dv, dest_path)

    # example_email_send_message_flow(['@gmail.com'])

if __name__ == "__main__":
    main_flow()
# Out:
# Overwriting ./pycode/orchestrate.py

# %%
# !python ./pycode/orchestrate.py --months="2 3 4"
# Out:
# 11558.72s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# 13:19:46.042 | INFO    | prefect.engine - Created flow run 'active-mastiff' for flow 'Main Flow'
# 13:19:46.047 | INFO    | Flow run 'active-mastiff' - View at http://127.0.0.1:4200/flow-runs/flow-run/19c8b226-06ec-4107-92b5-b4e213e378a8
# 2023/07/03 13:19:46 INFO mlflow.store.db.utils: Creating initial MLflow database tables...
# 2023/07/03 13:19:46 INFO mlflow.store.db.utils: Updating database tables
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 13:19:47.203 | INFO    | Flow run 'active-mastiff' - Created subflow run 'sociable-bittern' for flow 'Subflow Download Data'
# 13:19:47.206 | INFO    | Flow run 'sociable-bittern' - View at http://127.0.0.1:4200/flow-runs/flow-run/23ad19c9-8d7b-49ec-91db-4aa0ada791b7
# 13:19:47.470 | INFO    | Flow run 'sociable-bittern' - Created task run 'Fetch Data-0' for task 'Fetch Data'
# 13:19:47.473 | INFO    | Flow run 'sociable-bittern' - Executing 'Fetch Data-0' immediately...
# 13:19:47.629 | INFO    | Task run 'Fetch Data-0' - Finished in state Cached(type=COMPLETED)
# 13:19:47.700 | INFO    | Flow run 'sociable-bittern' - Created task run 'Fetch Data-1' for task 'Fetch Data'
# 13:19:47.702 | INFO    | Flow run 'sociable-bittern' - Executing 'Fetch Data-1' immediately...
# 13:19:47.855 | INFO    | Task run 'Fetch Data-1' - Finished in state Cached(type=COMPLETED)
# 13:19:47.930 | INFO    | Flow run 'sociable-bittern' - Created task run 'Fetch Data-2' for task 'Fetch Data'
# 13:19:47.931 | INFO    | Flow run 'sociable-bittern' - Executing 'Fetch Data-2' immediately...
# 13:19:48.057 | INFO    | Task run 'Fetch Data-2' - Finished in state Cached(type=COMPLETED)
# 13:19:48.292 | INFO    | Flow run 'sociable-bittern' - Finished in state Completed('All states completed.')
# 13:19:48.375 | INFO    | Flow run 'active-mastiff' - Created task run 'Read Taxi Data-0' for task 'Read Taxi Data'
# 13:19:48.376 | INFO    | Flow run 'active-mastiff' - Executing 'Read Taxi Data-0' immediately...
# 13:19:49.108 | INFO    | Task run 'Read Taxi Data-0' - Finished in state Completed()
# 13:19:49.168 | INFO    | Flow run 'active-mastiff' - Created task run 'Read Taxi Data-1' for task 'Read Taxi Data'
# 13:19:49.170 | INFO    | Flow run 'active-mastiff' - Executing 'Read Taxi Data-1' immediately...
# 13:19:49.957 | INFO    | Task run 'Read Taxi Data-1' - Finished in state Completed()
# 13:19:50.013 | INFO    | Flow run 'active-mastiff' - Created task run 'Read Taxi Data-2' for task 'Read Taxi Data'
# 13:19:50.015 | INFO    | Flow run 'active-mastiff' - Executing 'Read Taxi Data-2' immediately...
# 13:19:50.697 | INFO    | Task run 'Read Taxi Data-2' - Finished in state Completed()
# 13:19:50.759 | INFO    | Flow run 'active-mastiff' - Created task run 'Add Features Taxi Data-0' for task 'Add Features Taxi Data'
# 13:19:50.761 | INFO    | Flow run 'active-mastiff' - Executing 'Add Features Taxi Data-0' immediately...
# 13:19:52.139 | INFO    | Task run 'Add Features Taxi Data-0' - Finished in state Completed()
# 13:19:52.199 | INFO    | Flow run 'active-mastiff' - Created task run 'Train Best Model-0' for task 'Train Best Model'
# 13:19:52.201 | INFO    | Flow run 'active-mastiff' - Executing 'Train Best Model-0' immediately...
# [13:19:54] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# 13:19:55.020 | INFO    | Task run 'Train Best Model-0' - [0]    validation-rmse:15.33078
# 13:19:57.648 | INFO    | Task run 'Train Best Model-0' - [1]    validation-rmse:14.09739
# 13:19:58.633 | INFO    | Task run 'Train Best Model-0' - [2]    validation-rmse:12.99920
# 13:19:58.909 | INFO    | Task run 'Train Best Model-0' - [3]    validation-rmse:12.02243
# 13:19:59.270 | INFO    | Task run 'Train Best Model-0' - [4]    validation-rmse:11.15585
# 13:19:59.602 | INFO    | Task run 'Train Best Model-0' - [5]    validation-rmse:10.39226
# 13:20:00.290 | INFO    | Task run 'Train Best Model-0' - [6]    validation-rmse:9.71696
# 13:20:02.174 | INFO    | Task run 'Train Best Model-0' - [7]    validation-rmse:9.12782
# 13:20:02.639 | INFO    | Task run 'Train Best Model-0' - [8]    validation-rmse:8.60975
# 13:20:03.027 | INFO    | Task run 'Train Best Model-0' - [9]    validation-rmse:8.15872
# 13:20:03.381 | INFO    | Task run 'Train Best Model-0' - [10]   validation-rmse:7.76686
# 13:20:03.852 | INFO    | Task run 'Train Best Model-0' - [11]   validation-rmse:7.42798
# 13:20:04.319 | INFO    | Task run 'Train Best Model-0' - [12]   validation-rmse:7.13629
# 13:20:04.631 | INFO    | Task run 'Train Best Model-0' - [13]   validation-rmse:6.88486
# 13:20:04.976 | INFO    | Task run 'Train Best Model-0' - [14]   validation-rmse:6.67077
# 13:20:05.251 | INFO    | Task run 'Train Best Model-0' - [15]   validation-rmse:6.48829
# 13:20:05.595 | INFO    | Task run 'Train Best Model-0' - [16]   validation-rmse:6.33274
# 13:20:05.835 | INFO    | Task run 'Train Best Model-0' - [17]   validation-rmse:6.19826
# 13:20:06.148 | INFO    | Task run 'Train Best Model-0' - [18]   validation-rmse:6.08427
# 13:20:06.422 | INFO    | Task run 'Train Best Model-0' - [19]   validation-rmse:5.98670
# 13:20:06.654 | INFO    | Task run 'Train Best Model-0' - [20]   validation-rmse:5.90483
# 13:20:06.945 | INFO    | Task run 'Train Best Model-0' - [21]   validation-rmse:5.83439
# 13:20:07.276 | INFO    | Task run 'Train Best Model-0' - [22]   validation-rmse:5.77680
# 13:20:07.482 | INFO    | Task run 'Train Best Model-0' - [23]   validation-rmse:5.72543
# 13:20:07.730 | INFO    | Task run 'Train Best Model-0' - [24]   validation-rmse:5.68091
# 13:20:08.003 | INFO    | Task run 'Train Best Model-0' - [25]   validation-rmse:5.64424
# 13:20:08.437 | INFO    | Task run 'Train Best Model-0' - [26]   validation-rmse:5.61182
# 13:20:08.673 | INFO    | Task run 'Train Best Model-0' - [27]   validation-rmse:5.58395
# 13:20:08.901 | INFO    | Task run 'Train Best Model-0' - [28]   validation-rmse:5.56122
# 13:20:09.100 | INFO    | Task run 'Train Best Model-0' - [29]   validation-rmse:5.54000
# 13:20:10.157 | INFO    | Task run 'Train Best Model-0' - [30]   validation-rmse:5.52124
# 13:20:10.441 | INFO    | Task run 'Train Best Model-0' - [31]   validation-rmse:5.50483
# 13:20:10.619 | INFO    | Task run 'Train Best Model-0' - [32]   validation-rmse:5.49293
# 13:20:10.870 | INFO    | Task run 'Train Best Model-0' - [33]   validation-rmse:5.48085
# 13:20:11.095 | INFO    | Task run 'Train Best Model-0' - [34]   validation-rmse:5.47086
# 13:20:11.339 | INFO    | Task run 'Train Best Model-0' - [35]   validation-rmse:5.46186
# 13:20:11.550 | INFO    | Task run 'Train Best Model-0' - [36]   validation-rmse:5.45498
# 13:20:11.920 | INFO    | Task run 'Train Best Model-0' - [37]   validation-rmse:5.44771
# 13:20:12.281 | INFO    | Task run 'Train Best Model-0' - [38]   validation-rmse:5.44088
# 13:20:12.568 | INFO    | Task run 'Train Best Model-0' - [39]   validation-rmse:5.43434
# 13:20:12.894 | INFO    | Task run 'Train Best Model-0' - [40]   validation-rmse:5.43017
# 13:20:13.135 | INFO    | Task run 'Train Best Model-0' - [41]   validation-rmse:5.42578
# 13:20:13.298 | INFO    | Task run 'Train Best Model-0' - [42]   validation-rmse:5.42230
# 13:20:13.464 | INFO    | Task run 'Train Best Model-0' - [43]   validation-rmse:5.41903
# 13:20:13.629 | INFO    | Task run 'Train Best Model-0' - [44]   validation-rmse:5.41589
# 13:20:13.752 | INFO    | Task run 'Train Best Model-0' - [45]   validation-rmse:5.41305
# 13:20:13.930 | INFO    | Task run 'Train Best Model-0' - [46]   validation-rmse:5.41009
# 13:20:14.133 | INFO    | Task run 'Train Best Model-0' - [47]   validation-rmse:5.40823
# 13:20:14.408 | INFO    | Task run 'Train Best Model-0' - [48]   validation-rmse:5.40656
# 13:20:14.616 | INFO    | Task run 'Train Best Model-0' - [49]   validation-rmse:5.40523
# 13:20:14.876 | INFO    | Task run 'Train Best Model-0' - [50]   validation-rmse:5.40380
# 13:20:15.018 | INFO    | Task run 'Train Best Model-0' - [51]   validation-rmse:5.40214
# 13:20:15.308 | INFO    | Task run 'Train Best Model-0' - [52]   validation-rmse:5.40109
# 13:20:15.510 | INFO    | Task run 'Train Best Model-0' - [53]   validation-rmse:5.40025
# 13:20:15.739 | INFO    | Task run 'Train Best Model-0' - [54]   validation-rmse:5.39867
# 13:20:16.113 | INFO    | Task run 'Train Best Model-0' - [55]   validation-rmse:5.39758
# 13:20:16.315 | INFO    | Task run 'Train Best Model-0' - [56]   validation-rmse:5.39653
# 13:20:16.473 | INFO    | Task run 'Train Best Model-0' - [57]   validation-rmse:5.39541
# 13:20:16.816 | INFO    | Task run 'Train Best Model-0' - [58]   validation-rmse:5.39468
# 13:20:17.030 | INFO    | Task run 'Train Best Model-0' - [59]   validation-rmse:5.39393
# 13:20:17.290 | INFO    | Task run 'Train Best Model-0' - [60]   validation-rmse:5.39310
# 13:20:17.453 | INFO    | Task run 'Train Best Model-0' - [61]   validation-rmse:5.39250
# 13:20:17.625 | INFO    | Task run 'Train Best Model-0' - [62]   validation-rmse:5.39156
# 13:20:17.774 | INFO    | Task run 'Train Best Model-0' - [63]   validation-rmse:5.39117
# 13:20:17.969 | INFO    | Task run 'Train Best Model-0' - [64]   validation-rmse:5.39068
# 13:20:18.112 | INFO    | Task run 'Train Best Model-0' - [65]   validation-rmse:5.38985
# 13:20:18.309 | INFO    | Task run 'Train Best Model-0' - [66]   validation-rmse:5.38964
# 13:20:18.468 | INFO    | Task run 'Train Best Model-0' - [67]   validation-rmse:5.38894
# 13:20:18.607 | INFO    | Task run 'Train Best Model-0' - [68]   validation-rmse:5.38829
# 13:20:18.931 | INFO    | Task run 'Train Best Model-0' - [69]   validation-rmse:5.38770
# 13:20:19.094 | INFO    | Task run 'Train Best Model-0' - [70]   validation-rmse:5.38663
# 13:20:19.322 | INFO    | Task run 'Train Best Model-0' - [71]   validation-rmse:5.38621
# 13:20:19.524 | INFO    | Task run 'Train Best Model-0' - [72]   validation-rmse:5.38556
# 13:20:19.717 | INFO    | Task run 'Train Best Model-0' - [73]   validation-rmse:5.38495
# 13:20:19.973 | INFO    | Task run 'Train Best Model-0' - [74]   validation-rmse:5.38442
# 13:20:20.166 | INFO    | Task run 'Train Best Model-0' - [75]   validation-rmse:5.38382
# 13:20:20.388 | INFO    | Task run 'Train Best Model-0' - [76]   validation-rmse:5.38359
# 13:20:20.561 | INFO    | Task run 'Train Best Model-0' - [77]   validation-rmse:5.38310
# 13:20:21.061 | INFO    | Task run 'Train Best Model-0' - [78]   validation-rmse:5.38273
# 13:20:21.293 | INFO    | Task run 'Train Best Model-0' - [79]   validation-rmse:5.38246
# 13:20:21.471 | INFO    | Task run 'Train Best Model-0' - [80]   validation-rmse:5.38223
# 13:20:21.624 | INFO    | Task run 'Train Best Model-0' - [81]   validation-rmse:5.38196
# 13:20:21.897 | INFO    | Task run 'Train Best Model-0' - [82]   validation-rmse:5.38102
# 13:20:22.087 | INFO    | Task run 'Train Best Model-0' - [83]   validation-rmse:5.38055
# 13:20:22.296 | INFO    | Task run 'Train Best Model-0' - [84]   validation-rmse:5.38044
# 13:20:22.441 | INFO    | Task run 'Train Best Model-0' - [85]   validation-rmse:5.38019
# 13:20:22.587 | INFO    | Task run 'Train Best Model-0' - [86]   validation-rmse:5.37990
# 13:20:22.728 | INFO    | Task run 'Train Best Model-0' - [87]   validation-rmse:5.37936
# 13:20:22.890 | INFO    | Task run 'Train Best Model-0' - [88]   validation-rmse:5.37883
# 13:20:23.054 | INFO    | Task run 'Train Best Model-0' - [89]   validation-rmse:5.37832
# 13:20:23.228 | INFO    | Task run 'Train Best Model-0' - [90]   validation-rmse:5.37805
# 13:20:23.358 | INFO    | Task run 'Train Best Model-0' - [91]   validation-rmse:5.37788
# 13:20:23.505 | INFO    | Task run 'Train Best Model-0' - [92]   validation-rmse:5.37722
# 13:20:23.638 | INFO    | Task run 'Train Best Model-0' - [93]   validation-rmse:5.37667
# 13:20:23.789 | INFO    | Task run 'Train Best Model-0' - [94]   validation-rmse:5.37631
# 13:20:24.003 | INFO    | Task run 'Train Best Model-0' - [95]   validation-rmse:5.37589
# 13:20:24.155 | INFO    | Task run 'Train Best Model-0' - [96]   validation-rmse:5.37561
# 13:20:24.360 | INFO    | Task run 'Train Best Model-0' - [97]   validation-rmse:5.37512
# 13:20:24.567 | INFO    | Task run 'Train Best Model-0' - [98]   validation-rmse:5.37468
# 13:20:24.729 | INFO    | Task run 'Train Best Model-0' - [99]   validation-rmse:5.37450
# 13:20:41.412 | INFO    | Task run 'Train Best Model-0' - Finished in state Completed()
# 13:20:41.508 | INFO    | Flow run 'active-mastiff' - Finished in state Completed('All states completed.')

# %% [markdown]
# - Start a worker that polls your work pool
# ```sh
# prefect deploy "./pycode/orchestrate.py:main_flow" -n "taxi_data-deployment" -p "zoom-pool"
# prefect deploy --all  # or
# ```

# %% [markdown]
# ```
# 31f95cf7
# Flow run
# wonderful-bat
# Task run
# Train Best Model-0
# RMSE for Validation Data Report
# RMSE for Validation Data
# RMSE: 5.374495195206525
#
#
# dc032057
# Flow run
# interesting-cougar
# Task run
# Train Best Model-0
# Created gtm-report
# ```

# %% [markdown]
# ## Q5. Emails
#
#
# It’s often helpful to be notified when something with your dataflow doesn’t work
# as planned. Create an email notification for to use with your own Prefect server instance.
# In your virtual environment, install the prefect-email integration with
#
# ```bash
# pip install prefect-email
# ```
#
# Make sure you are connected to a running Prefect server instance through your
# Prefect profile.
# See the docs if needed: https://docs.prefect.io/latest/concepts/settings/#configuration-profiles
#
# Register the new block with your server with
#
# ```bash
# prefect block register -m prefect_email
# ```
#
# Remember that a block is a Prefect class with a nice UI form interface.
# Block objects live on the server and can be created and accessed in your Python code.
#
# See the docs for how to authenticate by saving your email credentials to
# a block and note that you will need an App Password to send emails with
# Gmail and other services. Follow the instructions in the docs.
#
# Create and save an `EmailServerCredentials` notification block.
# Use the credentials block to send an email.
#
# Test the notification functionality by running a deployment.
#
# **What is the name of the pre-built prefect-email task function?**

# %%
# !prefect block register -m prefect_email
# Out:
# Successfully registered 1 block
#
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Registered Blocks        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Email Server Credentials │
# └──────────────────────────┘
#
#  To configure the newly registered blocks, go to the Blocks page in the Prefect
# UI.

# %%
from prefect_email import EmailServerCredentials

credentials = EmailServerCredentials(
    username="EMAIL-ADDRESS-PLACEHOLDER",
    password="PASSWORD-PLACEHOLDER",  # must be an app password
)
credentials.save("BLOCK-NAME-PLACEHOLDER")
# Out:
# <coroutine object Block.save at 0x7f5e362fb450>

# %%
from prefect_email import EmailServerCredentials

EmailServerCredentials.load("BLOCK_NAME_PLACEHOLDER")
# Out:
# <coroutine object Block.load at 0x7f5e362fb140>

# %%
# Send an email using Gmail
from prefect import flow
from prefect_email import EmailServerCredentials, email_send_message

@flow(name="Email Server Credentials")
def example_email_send_message_flow():
    email_server_credentials = EmailServerCredentials(
        username="your_email_address@gmail.com",
        password="MUST_be_an_app_password_here!",
    )
    # email_server_credentials.save("BLOCK-NAME-PLACEHOLDER")
    # email_server_credentials = EmailServerCredentials.load("BLOCK_NAME_PLACEHOLDER")
    
    subject = email_send_message(
        email_server_credentials=email_server_credentials,
        subject="Example Flow Notification using Gmail",
        msg="This proves email_send_message works!",
        email_to="someone_awesome@gmail.com",
    )
    return subject

# example_email_send_message_flow()

# %% [markdown]
# ## Q6. Prefect Cloud
#
# The hosted Prefect Cloud lets you avoid running your own Prefect server and
# has automations that allow you to get notifications when certain events occur
# or don’t occur.
#
# Create a free forever Prefect Cloud account at [app.prefect.cloud](https://app.prefect.cloud/) and connect
# your workspace to it following the steps in the UI when you sign up.
#
# Set up an Automation from the UI that will send yourself an email when
# a flow run completes. Run one of your existing deployments and check
# your email to see the notification.
#
# Make sure your active profile is pointing toward Prefect Cloud and
# make sure you have a worker active.
#
# **What is the name of the second step in the Automation creation process?**

# %% [markdown]
# **Note:**
#
# - The name of the second step in the Automation creation process in Prefect Cloud is "Configure Triggers." This step allows you to define the conditions or events that will trigger the Automation to execute. In this case, you would configure the trigger to activate when a flow run completes.

# %% [markdown]
# # End of The Project
